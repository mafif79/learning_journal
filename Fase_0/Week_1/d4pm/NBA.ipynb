# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.shape[0]
# Out:
# 126314

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option('display.max.columns',None)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# Data Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# Data Exploration

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df['game_result']
# Out:
# 0         L
# 1         W
# 2         W
# 3         L
# 4         L
#          ..
# 126309    L
# 126310    W
# 126311    L
# 126312    L
# 126313    W
# Name: game_result, Length: 126314, dtype: object

# %%
df[['game_result','pts']]
# Out:
#        game_result  pts
# 0                L   66
# 1                W   68
# 2                W   63
# 3                L   47
# 4                L   33
# ...            ...  ...
# 126309           L   82
# 126310           W  104
# 126311           L   91
# 126312           L   97
# 126313           W  105
#
# [126314 rows x 2 columns]

# %%
df['game_result'].unique()
# Out:
# array(['L', 'W'], dtype=object)

# %%
df['game_result'].value_counts()
# Out:
# L    63157
# W    63157
# Name: game_result, dtype: int64

# %%
df['team_id'].value_counts().head()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %%
df.sort_values(by='pts', ascending=True).head()
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
# 26685      13343  197210260VIR   ABA        0     1973  10/26/1972
# 3190        1596  195011220LAL   NBA        0     1951  11/22/1950
# 3191        1596  195011220LAL   NBA        1     1951  11/22/1950
# 4              3  194611020DTF   NBA        0     1947   11/2/1946
#
#        seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 26684           7            0     DNR  Nuggets    0  1460.3387  1457.4464
# 26685           8            0     VIR  Squires    2  1484.1907  1487.0830
# 3190           10            0     MNL   Lakers   18  1659.4946  1650.9559
# 3191           12            0     FTW  Pistons   19  1487.9486  1496.4873
# 4               1            0     DTF  Falcons   33  1300.0000  1279.6189
#
#        win_equiv opp_id  opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.loc[2:7,'fran_id']
# Out:
# 2           Stags
# 3          Knicks
# 4         Falcons
# 5        Capitols
# 6         Celtics
# 7    Steamrollers
# Name: fran_id, dtype: object

# %%
df.loc[df['fran_id']=='Knicks',:]#Value yang mau diambil
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1               1  194611010TRH   NBA        1     1947   11/1/1946
# 3               2  194611020CHS   NBA        1     1947   11/2/1946
# 23             12  194611070STB   NBA        1     1947   11/7/1946
# 37             19  194611110NYK   NBA        0     1947  11/11/1946
# 54             28  194611160NYK   NBA        0     1947  11/16/1946
# ...           ...           ...   ...      ...      ...         ...
# 126025      63013  201504080NYK   NBA        0     2015    4/8/2015
# 126056      63029  201504100NYK   NBA        0     2015   4/10/2015
# 126072      63037  201504110ORL   NBA        1     2015   4/11/2015
# 126094      63048  201504130ATL   NBA        1     2015   4/13/2015
# 126147      63074  201504150NYK   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %%
df.loc[df['fran_id']=='Knicks',['year_id','fran_id','pts','opp_pts','opp_fran']]
# Out:
#         year_id fran_id  pts  opp_pts opp_fran
# 1          1947  Knicks   68       66  Huskies
# 3          1947  Knicks   47       63    Stags
# 23         1947  Knicks   68       63  Bombers
# 37         1947  Knicks   68       78    Stags
# 54         1947  Knicks   64       62  Ironmen
# ...         ...     ...  ...      ...      ...
# 126025     2015  Knicks   86      102   Pacers
# 126056     2015  Knicks   91       99    Bucks
# 126072     2015  Knicks   80       79    Magic
# 126094     2015  Knicks  112      108    Hawks
# 126147     2015  Knicks   90      112  Pistons
#
# [5769 rows x 5 columns]

# %%
df.loc[2:7,'fran_id']
# Out:
# 2           Stags
# 3          Knicks
# 4         Falcons
# 5        Capitols
# 6         Celtics
# 7    Steamrollers
# Name: fran_id, dtype: object

# %%
df.loc[df['fran_id']=='Lakers','team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['fran_id']=='Lakers','pts'].mean()
# Out:
# 105.81739707835325

# %%
df['pts'].loc[1:6]
# Out:
# 1    68
# 2    63
# 3    47
# 4    33
# 5    50
# 6    53
# Name: pts, dtype: int64

# %% [markdown]
# Query

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df[df['year_id']>2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
df[df['year_id']>2010]['pts']
# Out:
# 113656     80
# 113657     88
# 113658    110
# 113659    112
# 113660     92
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 12658, dtype: int64

# %%
#yaer_id diatas 2010
#fran_id Warriors
#pts diatas 100
#game_result W

df[
    (df['year_id']<2010)&
    (df['fran_id']=='Warriors')&
    (df['pts']>=100)&
    (df['game_result']=='W')
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 313           157  194701140TRH   NBA        1     1947  1/14/1947
# 623           312  194703220PRO   NBA        1     1947  3/22/1947
# 1065          533  194803160PRO   NBA        1     1948  3/16/1948
# 1497          749  194901140BOS   NBA        1     1949  1/14/1949
# 1571          786  194901270GSW   NBA        0     1949  1/27/1949
# ...           ...           ...   ...      ...      ...        ...
# 110450      55226  200903200GSW   NBA        0     2009  3/20/2009
# 110630      55316  200904010GSW   NBA        0     2009   4/1/2009
# 110655      55328  200904030GSW   NBA        0     2009   4/3/2009
# 110702      55352  200904050SAC   NBA        1     2009   4/5/2009
# 110790      55396  200904110UTA   NBA        1     2009  4/11/2009
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 313             28            0     PHW  Warriors  104  1312.5405  1338.6333
# ...

# %%
#yaer_id diatas 2010
#fran_id Warriors
#pts diatas 100
#game_result W

df.query("year_id>100 & fran_id == 'Warriors' & pts>=100 & game_result =='W'")
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 313           157  194701140TRH   NBA        1     1947  1/14/1947
# 623           312  194703220PRO   NBA        1     1947  3/22/1947
# 1065          533  194803160PRO   NBA        1     1948  3/16/1948
# 1497          749  194901140BOS   NBA        1     1949  1/14/1949
# 1571          786  194901270GSW   NBA        0     1949  1/27/1949
# ...           ...           ...   ...      ...      ...        ...
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 313             28            0     PHW  Warriors  104  1312.5405  1338.6333
# ...

# %%
df[
    (df ['year_id']<2013)&
    (df ['year_id']>2010)&
    (df['fran_id']=='Warriors')&
    (df['pts']>=100)&
    (df['game_result']=='W')
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113668      56835  201010270GSW   NBA        0     2011  10/27/2010
# 113700      56851  201010290GSW   NBA        0     2011  10/29/2010
# 113767      56884  201011030GSW   NBA        0     2011   11/3/2010
# 113853      56927  201011080TOR   NBA        1     2011   11/8/2010
# 113874      56938  201011100NYK   NBA        1     2011  11/10/2010
# 113944      56973  201011150GSW   NBA        0     2011  11/15/2010
# 114127      57064  201011270MIN   NBA        1     2011  11/27/2010
# 114379      57190  201012140GSW   NBA        0     2011  12/14/2010
# 114493      57247  201012210SAC   NBA        1     2011  12/21/2010
# 114519      57260  201012250GSW   NBA        0     2011  12/25/2010
# 114544      57273  201012270GSW   NBA        0     2011  12/27/2010
# 114688      57345  201101050NOH   NBA        1     2011    1/5/2011
# 114704      57353  201101070GSW   NBA        0     2011    1/7/2011
# ...

# %% [markdown]
# Grouping dan Agrregating

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.groupby('game_location')['pts'].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
grup=df.groupby('game_location')
grup

# %%
grup.get_group('A')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 1                1            0     NYK     Knicks   68  1300.0000  1306.7233
# ...

# %%
grup.get_group('H')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 0                1            0     TRH       Huskies   66  1300.0000
# ...

# %%
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %%
#chaining + groupby
df[
    (df ['year_id']>2012)&
    (df['fran_id']=='Spurs')&
    (df['game_result']=='W')
].groupby('year_id')['pts'].mean()
# Out:
# year_id
# 2013    106.232877
# 2014    108.564103
# 2015    106.224138
# Name: pts, dtype: float64

# %%
df[
    (df ['year_id']>2012)&
    (df['fran_id']=='Spurs')&
    (df['game_result']=='W')
].groupby(['year_id', 'game_location'])['pts'].mean()
# Out:
# year_id  game_location
# 2013     A                106.166667
#          H                106.279070
# 2014     A                108.200000
#          H                108.860465
# 2015     A                105.041667
#          H                107.058824
# Name: pts, dtype: float64

# %% [markdown]
# Tim Spurs pada tahun 2013 hingga 2014 memiliki rata2 oin kemenangan tertinggi di tahun 2014

# %%
df.groupby('fran_id')['pts'].mean().sort_values(ascending=True)
# Out:
# fran_id
# Ironmen          61.233333
# Falcons          63.283333
# Huskies          66.583333
# Rebels           71.015873
# Bombers          71.457831
# Steamrollers     73.642857
# Jets             74.700000
# Capitols         76.931271
# Denver           77.709677
# Stags            78.453846
# Waterloo         79.370968
# Baltimore        79.698073
# Olympians        81.078014
# Redskins         82.646154
# Packers          86.013889
# Hornets          94.506711
# Grizzlies        95.161738
# Heat             96.627162
# Raptors          96.921665
# Timberwolves     97.462694
# Pelicans         97.956522
# Magic            99.427277
# Cavaliers        99.846719
# Knicks          100.970185
# Pistons         101.373097
# Bulls           101.525192
# Nets            101.755723
# Hawks           101.805635
# Clippers        101.934905
# Jazz            102.153305
# Mavericks       102.634915
# Wizards         103.624836
# Pacers          103.687722
# Bucks           103.700050
# ...

# %%
df2=df.groupby('fran_id')[['pts']].mean()
df2[df2['pts']>100]
df2
# Out:
#                      pts
# fran_id
# Baltimore      79.698073
# Bombers        71.457831
# Bucks         103.700050
# Bulls         101.525192
# Capitols       76.931271
# Cavaliers      99.846719
# Celtics       104.466233
# Clippers      101.934905
# Colonels      111.625296
# Condors       115.446512
# Denver         77.709677
# Falcons        63.283333
# Floridians    112.654545
# Grizzlies      95.161738
# Hawks         101.805635
# Heat           96.627162
# Hornets        94.506711
# Huskies        66.583333
# Ironmen        61.233333
# Jazz          102.153305
# Jets           74.700000
# Kings         103.971689
# Knicks        100.970185
# Lakers        105.817397
# Magic          99.427277
# Mavericks     102.634915
# Nets          101.755723
# Nuggets       108.199029
# Olympians      81.078014
# Pacers        103.687722
# Packers        86.013889
# Pelicans       97.956522
# Pistons       101.373097
# Raptors        96.921665
# Rebels         71.015873
# ...

# %% [markdown]
# Column Manipulation

# %%
df_new = df.copy()
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
import numpy as np
#create new column
df_new['selisi_poin'] = df_new['pts']-df_new['opp_pts']
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#rename columns
df_new.rename(columns={'game_location':'loc','game_result':'result'},inplace=True)
            #inplace=True biar tersimpan
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#Drop Column
df_new.drop(['elo_i','elo_n'],axis=1,inplace=True)
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n loc result  forecast notes  selisi_poin
# ...

# %% [markdown]
# Mengetahui nilai diatas rata2

# %%
mean_pts=df['pts'].mean()
mean_pts
# Out:
# 102.72998242475101

# %%
df[df['pts']>mean_pts]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 256           129  194701010CHS   NBA        1     1947   1/1/1947
# 313           157  194701140TRH   NBA        1     1947  1/14/1947
# 399           200  194702020CLR   NBA        1     1947   2/2/1947
# 416           209  194702060CHS   NBA        0     1947   2/6/1947
# 561           281  194703080CHS   NBA        0     1947   3/8/1947
# ...           ...           ...   ...      ...      ...        ...
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 256             26            0     STB   Bombers  103  1341.3654  1359.0022
# ...

# %%
df[df['pts']>mean_pts]['pts'].min()
# Out:
# 103
