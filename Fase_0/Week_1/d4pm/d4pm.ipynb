# %%
import pandas as pd

# %%
pd.read_csv('../dataset/Student_Marks.csv')
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
pd.read_csv('../dataset/ref.csv', delimiter=';')
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.shape[0]
# Out:
# 126314

# %%
df.shape[1]
# Out:
# 23

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# ## **Data Overview**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# ## **DATA EXPLORATION**

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df['game_result'].unique()
# Out:
# array(['L', 'W'], dtype=object)

# %%
df['game_result'].value_counts()
# Out:
# L    63157
# W    63157
# Name: game_result, dtype: int64

# %%
df['team_id'].value_counts().head()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %%
df[['game_result', 'pts']]
# Out:
#        game_result  pts
# 0                L   66
# 1                W   68
# 2                W   63
# 3                L   47
# 4                L   33
# ...            ...  ...
# 126309           L   82
# 126310           W  104
# 126311           L   91
# 126312           L   97
# 126313           W  105
#
# [126314 rows x 2 columns]

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.sort_values(by='pts', ascending=False).head()
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 50094      25048  198312130DEN   NBA        1     1984  12/13/1983
# 50095      25048  198312130DEN   NBA        0     1984  12/13/1983
# 21416      10709  197004120INA   ABA        0     1970   4/12/1970
# 32881      16441  197502140SDA   ABA        0     1975   2/14/1975
# 8974        4488  195902270BOS   NBA        0     1959   2/27/1959
#
#        seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 50094          23            0     DET  Pistons  186  1491.8865  1499.0237
# 50095          23            0     DEN  Nuggets  184  1512.6967  1505.5594
# 21416          82            0     INA   Pacers  177  1432.5527  1441.0964
# 32881          59            0     SDA    Sails  176  1372.6880  1390.9362
# 8974           66            0     BOS  Celtics  173  1671.0728  1678.0564
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.loc[df["fran_id"] == "Lakers",'team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df["fran_id"] == "Lakers",'pts'].mean()
# Out:
# 105.81739707835325

# %%
df['pts'].loc[1:6]
# Out:
# 1    68
# 2    63
# 3    47
# 4    33
# 5    50
# 6    53
# Name: pts, dtype: int64

# %% [markdown]
# ## **Query**

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df[df['year_id']>2010]['pts']
# Out:
# 113656     80
# 113657     88
# 113658    110
# 113659    112
# 113660     92
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 12658, dtype: int64

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
# year_id diatas 2010
# fran_id Warriors
# pts diatas 100
# game_result W

df[
    (df['year_id'] > 2010) &
    (df['fran_id'] == 'Warriors') &
    (df['pts'] >= 100) &
    (df['game_result'] == 'W')
][['year_id', 'fran_id', 'pts', 'opp_pts', 'opp_fran', 'game_result']]
# Out:
#         year_id   fran_id  pts  opp_pts   opp_fran game_result
# 113668     2011  Warriors  132      128    Rockets           W
# 113700     2011  Warriors  109       91   Clippers           W
# 113767     2011  Warriors  115      109  Grizzlies           W
# 113853     2011  Warriors  109      102    Raptors           W
# 113874     2011  Warriors  122      117     Knicks           W
# ...         ...       ...  ...      ...        ...         ...
# 126301     2015  Warriors  104       90    Rockets           W
# 126303     2015  Warriors  108      100  Cavaliers           W
# 126308     2015  Warriors  103       82  Cavaliers           W
# 126310     2015  Warriors  104       91  Cavaliers           W
# 126313     2015  Warriors  105       97  Cavaliers           W
#
# [201 rows x 6 columns]

# %%
# year_id diatas 2010
# fran_id Warriors
# pts diatas 100
# game_result W

df.query("year_id > 2010 & fran_id == 'Warriors' & pts >= 100 & game_result == 'W'")[['year_id', 'fran_id', 'pts', 'opp_pts', 'opp_fran', 'game_result']]
# Out:
#         year_id   fran_id  pts  opp_pts   opp_fran game_result
# 113668     2011  Warriors  132      128    Rockets           W
# 113700     2011  Warriors  109       91   Clippers           W
# 113767     2011  Warriors  115      109  Grizzlies           W
# 113853     2011  Warriors  109      102    Raptors           W
# 113874     2011  Warriors  122      117     Knicks           W
# ...         ...       ...  ...      ...        ...         ...
# 126301     2015  Warriors  104       90    Rockets           W
# 126303     2015  Warriors  108      100  Cavaliers           W
# 126308     2015  Warriors  103       82  Cavaliers           W
# 126310     2015  Warriors  104       91  Cavaliers           W
# 126313     2015  Warriors  105       97  Cavaliers           W
#
# [201 rows x 6 columns]

# %%
# year_id diatas 2010
# fran_id Warriors
# pts diatas 100
# game_result W

df[
    (df['year_id'] < 2013) &
    (df['year_id'] > 2010) &
    (df['fran_id'] == 'Warriors') &
    (df['pts'] >= 100) &
    (df['game_result'] == 'W')
]['year_id']
# Out:
# 113668    2011
# 113700    2011
# 113767    2011
# 113853    2011
# 113874    2011
# 113944    2011
# 114127    2011
# 114379    2011
# 114493    2011
# 114519    2011
# 114544    2011
# 114688    2011
# 114704    2011
# 114805    2011
# 114853    2011
# 114884    2011
# 114917    2011
# 115111    2011
# 115145    2011
# 115198    2011
# 115265    2011
# 115289    2011
# 115320    2011
# 115472    2011
# 115588    2011
# 115625    2011
# 115797    2011
# 115828    2011
# 115975    2011
# 116096    2011
# 116544    2012
# 116668    2012
# 116799    2012
# 116930    2012
# 117046    2012
# 117098    2012
# 117108    2012
# 117222    2012
# 117269    2012
# 117401    2012
# 117469    2012
# 117526    2012
# 117651    2012
# 117698    2012
# 117930    2012
# Name: year_id, dtype: int64

# %% [markdown]
# ## **GROUPING AND AGGREGATING**

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.groupby('fran_id')['pts'].mean()
# Out:
# fran_id
# Baltimore        79.698073
# Bombers          71.457831
# Bucks           103.700050
# Bulls           101.525192
# Capitols         76.931271
# Cavaliers        99.846719
# Celtics         104.466233
# Clippers        101.934905
# Colonels        111.625296
# Condors         115.446512
# Denver           77.709677
# Falcons          63.283333
# Floridians      112.654545
# Grizzlies        95.161738
# Hawks           101.805635
# Heat             96.627162
# Hornets          94.506711
# Huskies          66.583333
# Ironmen          61.233333
# Jazz            102.153305
# Jets             74.700000
# Kings           103.971689
# Knicks          100.970185
# Lakers          105.817397
# Magic            99.427277
# Mavericks       102.634915
# Nets            101.755723
# Nuggets         108.199029
# Olympians        81.078014
# Pacers          103.687722
# Packers          86.013889
# Pelicans         97.956522
# Pistons         101.373097
# Raptors          96.921665
# ...

# %%
df.groupby('game_location')['pts'].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
# contoh
grup = df.groupby('game_location')
grup

# %%
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 120711      60356  201304060SAS   NBA        1     2013   4/6/2013
# 100443      50222  200505100SAS   NBA        0     2005  5/10/2005
# 83867       41934  199902190TOR   NBA        1     1999  2/19/1999
# 51433       25717  198404130CHI   NBA        1     1984  4/13/1984
# 64357       32179  199011070MIN   NBA        0     1991  11/7/1990
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 120711          78            0     ATL         Hawks   97  1485.9762
# 100443          89            1     SAS         Spurs  108  1692.3411
# 83867            7            0     MIL         Bucks   82  1496.4980
# 51433           81            0     MIL         Bucks  109  1618.4432
# 64357            4            0     MIN  Timberwolves   91  1386.7175
#
#             elo_n  win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
# chaining query + groupby
df[
    (df['year_id']>2012) &
    (df['fran_id']=='Spurs')&
    (df['game_result']=='W')
].groupby(['year_id', 'game_location'])['pts'].mean()
# Out:
# year_id  game_location
# 2013     A                106.166667
#          H                106.279070
# 2014     A                108.200000
#          H                108.860465
# 2015     A                105.041667
#          H                107.058824
# Name: pts, dtype: float64

# %% [markdown]
# Tim Spurs pada tahun 2013 hingga 2014 memiliki rata-rata poin kemenangan tertinggi di tahun 2014.

# %%
df2 = df.groupby('fran_id')[['pts']].mean()
df2[df2['pts']>=100]
# Out:
#                      pts
# fran_id
# Bucks         103.700050
# Bulls         101.525192
# Celtics       104.466233
# Clippers      101.934905
# Colonels      111.625296
# Condors       115.446512
# Floridians    112.654545
# Hawks         101.805635
# Jazz          102.153305
# Kings         103.971689
# Knicks        100.970185
# Lakers        105.817397
# Mavericks     102.634915
# Nets          101.755723
# Nuggets       108.199029
# Pacers        103.687722
# Pistons       101.373097
# Rockets       104.117477
# Sails         109.781022
# Sixers        103.807760
# Sounds        108.439024
# Spirits       110.519949
# Spurs         105.319564
# Squires       114.051314
# Stars         112.354497
# Suns          107.226961
# Thunder       104.771422
# Trailblazers  104.055556
# Warriors      104.511932
# Wizards       103.624836

# %% [markdown]
# ## **column manipulation**
#
# - create new column
# - rename column
# - drop column

# %%
df_new = df.copy()
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# create new columns
df_new['selisih_poin'] = np.abs(df_new['pts'] - df_new['opp_pts'])
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n loc result  forecast notes  selisih_poin
# ...

# %%
# rename column
df_new.rename(columns={'game_location': 'loc',
                        'game_result': 'result'}, inplace=True)

# %%
df_new
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
# drop column
df_new.drop(['elo_i', 'elo_n'], axis=1, inplace=True)

# %% [markdown]
# # mengetahui nilai diatas rata-rata

# %%
import numpy as np

mean_pts = df['pts'].mean()
np.abs(mean_pts)
# Out:
# 102.72998242475101

# %%
mean_pts = df['pts'].mean()
# df[df['pts']> mean_pts]['pts'].min()
df[df['pts']> mean_pts]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 256           129  194701010CHS   NBA        1     1947   1/1/1947
# 313           157  194701140TRH   NBA        1     1947  1/14/1947
# 399           200  194702020CLR   NBA        1     1947   2/2/1947
# 416           209  194702060CHS   NBA        0     1947   2/6/1947
# 561           281  194703080CHS   NBA        0     1947   3/8/1947
# ...           ...           ...   ...      ...      ...        ...
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 256             26            0     STB   Bombers  103  1341.3654  1359.0022
# ...
